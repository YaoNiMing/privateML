# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import requests
from bs4 import BeautifulSoup

import time
import os
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy
import seaborn as sns
from seaborn import plt
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import RidgeCV
# Out:
# /Users/zach/anaconda/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#####

# %%
# To add delay when you are scrapping inside a Loop

time.sleep(np.random.random())

# %%
#only run once -- RUN AND DONE


def scrape_top(num):
    headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_5)'}
    base_url = 'http://www.boxofficemojo.com/alltime/domestic.htm'
    for a in range(int(num/100)):
        url = base_url
        if a > 0:
            url = "{}?page={}&p=.htm".format(base_url, a+1)
        resp = requests.get(url, headers=headers)
        file_name = "Domestic_List/Domestic_List_Page_{}.html".format(a+1)
        if resp.ok:
            soup = BeautifulSoup(resp.text, 'lxml')
            with open(file_name, 'w') as f:
                f.write(resp.text)
        print("Page {} done".format(a+1))

#DO NOT RUN THE FUNCTION BELOW UNLESS Domestic_List/ DIRECTORY WAS DELETED
#scrape_top(1200)
# Out:
# Page 1 done
# Page 2 done
# Page 3 done
# Page 4 done
# Page 5 done
# Page 6 done
# Page 7 done
# Page 8 done
# Page 9 done
# Page 10 done
# Page 11 done
# Page 12 done

# %%
#iterate through files in a directory
'''
for filename in os.listdir(directory):
    if filename.endswith(".asm") or filename.endswith(".py"): 
        # print(os.path.join(directory, filename))
        continue
    else:
        continue
'''

#soup.find(class_='mp_box_content').find_all('td'))

# %%
'''response = requests.get("https://en.wikipedia.org/wiki/List_of_highest-grossing_films")
soup = BeautifulSoup(response.text)

movie_list = soup.find("table",{ "class" : "wikitable sortable plainrowheaders" })
print(movie_list)

---------------------

movie_data = []

header = ['Rank','Peak','Worldwide Gross','Year','Reference(s)']
for row in movie_list.findAll("tr"):
    row_dict={}
    for i,cell in enumerate(row.findAll("td")):
        row_dict[header[i]] = cell.find(text=True)
    link = row.find("th").find("a")
    if link:
        row_dict['Title'] = link.text
    movie_data.append(row_dict)
    
movies_df = pd.DataFrame(movie_data)
movies_df.dropna()'''

# %%
print(os.listdir('domestic_list') if file.endswith(".html"))
# Out:
#   File "<ipython-input-3-cb1ac710186e>", line 1
#     print(os.listdir('domestic_list') if file.endswith(".html"))
#                                                                ^
# SyntaxError: invalid syntax

# %%
#Scrape movie name, boxofficemojo id, and create url from local files

df_columns = ['RANK','TITLE','STUDIO','LIFETIME GROSS','YEAR','BOM ID','URL']
temp_top_movie_list = []
top_movie_list = {}

def movie_list_df(directory):
    for file in os.listdir(directory):
        print(file)
        #top_movie_list = []
    #file = "{}/domestic_list_page_1".format(directory)
    #for i in range(1):
        if file.endswith(".html"):
            with open(directory + '/' + file, 'r') as f:
                soup = BeautifulSoup(f.read(), "lxml")
                #print(soup.prettify())
            #temp_top_movie_list = 
            temp_top_movie_list = (soup.find('div', {'id' : 'body'})
             .find('table', {'cellpadding' : '2'})
             .find('table', {"bgcolor" : '#ffffff'})
             .find('table', {'cellpadding':'5'})
             #.find('tbody')
             #.find_all('tr', {'bgcolor':'#ffffff'})
             #.find_all('tr', {'bgcolor':['#ffffff','#f4f4ff']})
             #.find_all(bgcolor_ != '#dcdcdc')
            )
            file_num = file.split('_')[-1].split('.html')[0]
            #print(temp_top_movie_list)
            #print(temp_top_movie_list)
            print(file_num)
            top_movie_list[file_num] = """<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">"
            """
            top_movie_list[file_num] = top_movie_list[file_num] + str(temp_top_movie_list)
            
            
            
movie_list_df("domestic_list")
print(top_movie_list)
# Out:
# .DS_Store
# Domestic_List_Page_1.html
# 1
# Domestic_List_Page_10.html
# 10
# Domestic_List_Page_11.html
# 11
# Domestic_List_Page_12.html
# 12
# Domestic_List_Page_2.html
# 2
# Domestic_List_Page_3.html
# 3
# Domestic_List_Page_4.html
# 4
# Domestic_List_Page_5.html
# 5
# Domestic_List_Page_6.html
# 6
# Domestic_List_Page_7.html
# 7
# Domestic_List_Page_8.html
# 8
# Domestic_List_Page_9.html
# 9
# ...

# %%
print(top_movie_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b3fe83d9d3b6> in <module>()
# ----> 1 print(top_movie_list)
#
# NameError: name 'top_movie_list' is not defined

# %%
'''response = requests.get("https://en.wikipedia.org/wiki/List_of_highest-grossing_films")
soup = BeautifulSoup(response.text)

movie_list = soup.find("table",{ "class" : "wikitable sortable plainrowheaders" })
print(movie_list)

---------------------

movie_data = []

header = ['Rank','Peak','Worldwide Gross','Year','Reference(s)']
for row in movie_list.findAll("tr"):
    row_dict={}
    for i,cell in enumerate(row.findAll("td")):
        row_dict[header[i]] = cell.find(text=True)
    link = row.find("th").find("a")
    if link:
        row_dict['Title'] = link.text
    movie_data.append(row_dict)
    
movies_df = pd.DataFrame(movie_data)
movies_df.dropna()'''
#scrape dictionary tables into a dataframe
movie_list_df = []

def dict_to_df(dct, df):
    for i in dct:

# %%
###DOWNLOADS PAGES FOR TOP <NUM> MOVIES; for me, it's 1200
def scrape_top(num):
    headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_5)'}
    base_url = 'http://www.boxofficemojo.com/alltime/domestic.htm'
    for a in range(int(num/100)):
        url = base_url
        if a > 0:
            url = "{}?page={}&p=.htm".format(base_url, a+1)
        resp = requests.get(url, headers=headers)
        file_name = "Domestic_List/Domestic_List_Page_{}.html".format(a+1)
        if resp.ok:
            soup = BeautifulSoup(resp.text, 'lxml')
            with open(file_name, 'w') as f:
                f.write(resp.text)
        print("Page {} done".format(a+1))

# %%
#downloads the pages for top 1200 movies
#base_url: http://www.boxofficemojo.com/movies/?id=starwars7.htm

def scrape_1200_saves(df):
    headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_5)'}
    for row in df:
        temp_url = "http://www.boxofficemojo.com/movies/?id={}.htm".format(df['BOM ID'])
        resp = requests.get(temp_url, headers=headers)
        file_name = 'movies/{}.html'.format(df['BOM ID'])
        oscars_file_name = 'oscars/movies/{}_oscars.html'.format(df['BOM ID'])
        if resp.ok:
            soup = BeautifulSoup(resp.text, 'lxml')
            with open (file_name, 'w') as f:
                f.write(resp.text)
            print("{} done".format(df['BOM ID']))
            soup.find('div', {'id':'body'}).find('table', {'width':'100%'}).find('table', {'width':'878px'}).find('div', class_='mp_box_content')

# %%
###SCRAPES LIFETIME GROSS, RANK, STUIDO, TITLE, YEAR so far... 
# working on 'BOM ID' and URL

df_columns = ['RANK','TITLE','STUDIO','LIFETIME GROSS','YEAR','BOM ID','URL']
movie_data_1 = []
row_dict = {}

top_movies_df = {}
def top_movies_df_creator(d):
    for entry in d:
        #print(d[entry])
        #.find('table', {'cellpadding':'5'})
        temp_soup = BeautifulSoup(d[entry], 'lxml')
        temp_soup_2 = temp_soup.find('table')
        #print (temp_soup_2)
        for row in temp_soup_2.find_all('tr'):
            row_dict = {}
            for i,cell in enumerate(row.findAll("td")):
                row_dict[df_columns[i]] = cell.find(text=True)
            bom_id = row.find('a')["href"].split('id=')[-1].split('.ht')[0]
            #bom_id = ABOVE^^^
            
            row_dict['BOM_ID'] = bom_id
            #link = row.find("th").find("a")
            #if link:
                #row_dict['Title'] = link.text
            movie_data_1.append(row_dict)
            #print(row_dict)
            
            
top_movies_df_creator(top_movie_list)            
top_movies_df_1 = pd.DataFrame(movie_data_1)
#top_movies_df_1.info
#print(movie_data_1)

# %%
top_movies_df_1 = top_movies_df_1[~top_movies_df_1.YEAR.str.startswith("Year")]

# %%
def clean_year(value):
    value = value.strip()
    if value[-1] == "^":
        value = value[:-1]
    return value

top_movies_df_1["YEAR"] = top_movies_df_1['YEAR'].map(clean_year)

# %%
top_movies_df_1.YEAR.unique()
# Out:
# array(['2006', '1997', '2004', '1981', '1999', '2014', '2003', '1984',
#        '1996', '2002', '2011', '2010', '2013', '2012', '2005', '2000',
#        '1973', '2015', '2008', '2007', '2001', '2009', '1993', '1991',
#        '1990', '1992', '1998', '1985', '1939', '1989', '1995', '1978',
#        '1937', '2016', '1969', '1964', '1942', '1994', '1980', '1970',
#        '1977', '1955', '1976', '1979', '1986', '1982', '1983', '1987',
#        '1950', '1953', '1974', '1972', '1940', '1988', '1965', '1975',
#        '1967', '1956', '1961', '1941', '1959'], dtype=object)

# %%
top_movies_df_1['YEAR'] = top_movies_df_1['YEAR'].astype(int)

top_movies_df_1
# Out:
#                           BOM_ID LIFETIME GROSS  RANK   STUDIO  \
# 1                         butler   $116,632,095   501    Wein.
# 2                   greenlantern   $116,601,172   502       WB
# 3                    nottinghill   $116,089,678   503     Uni.
# 4                toweringinferno   $116,000,000   504      Fox
# 5                   youvegotmail   $115,821,495   505       WB
# 6                     ghostrider   $115,802,596   506     Sony
# 7              rememberthetitans   $115,654,751   507       BV
# 8                      district9   $115,646,235   508     TriS
# 9                       unbroken   $115,637,895   509     Uni.
# 10                    karatekid2   $115,103,979   510     Col.
# 11              americangraffiti   $115,000,000   511     Uni.
# 12                           big   $114,968,774   512      Fox
# 13                     dodgeball   $114,326,736   513      Fox
# 14                       village   $114,197,520   514       BV
# ...

# %%
##SAME AS ABOVE BUT going through all the files again instead of using a dictionary

###SAMPLE CODE
df_columns = ['RANK','TITLE','STUDIO','LIFETIME GROSS','YEAR','BOM ID','URL']
movie_data_1 = []
row_dict = {}

top_movies_df = {}
def top_movies_df_creator_2(d):
    for file in os.listdir(directory):
        print(file)
        if file.endswith(".html"):
            with open(directory + '/' + file, 'r') as f:
                soup = BeautifulSoup(f.read(), "lxml")
        #print(d[entry])
        #.find('table', {'cellpadding':'5'})
        temp_soup = BeautifulSoup(d[entry], 'lxml')
        temp_soup_2 = temp_soup.find('table')
        print (temp_soup_2)
        for row in temp_soup.findall('tr'):
            row_dict = {}
            for i,cell in enumerate(row.findAll("td")):
                row_dict[df_columns[i]] = cell.find(text=True)
            link = row.find("th").find("a")
            if link:
                row_dict['Title'] = link.text
            movie_data_1.append(row_dict)
            print(row_dict)

# %%
'''response = requests.get("https://en.wikipedia.org/wiki/List_of_highest-grossing_films")
soup = BeautifulSoup(response.text)

movie_list = soup.find("table",{ "class" : "wikitable sortable plainrowheaders" })
print(movie_list)

---------------------

movie_data = []

header = ['Rank','Peak','Worldwide Gross','Year','Reference(s)']
for row in movie_list.findAll("tr"):
    row_dict={}
    for i,cell in enumerate(row.findAll("td")):
        row_dict[header[i]] = cell.find(text=True)
    link = row.find("th").find("a")
    if link:
        row_dict['Title'] = link.text
    movie_data.append(row_dict)
    
movies_df = pd.DataFrame(movie_data)
movies_df.dropna()'''

# %%
top_movies_data = []
df_top_columns = ['RANK','TITLE','STUDIO','LIFETIME GROSS','YEAR','BOM ID','URL']

def top_movies_df_creator(lst):
    for a in lst:
        for row in

# %%
###INCOMPLETE ------------------
#code to download movie pages into local_files.html
def download_movies(url_list)
    headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_5)'}
    #url = "http://boxofficemojo.com/movies/?id=biglebowski.htm"
    resp = requests.get(url, headers=headers)
    if resp.ok:
        soup = BeautifulSoup(resp.text, 'lxml')
    
        file_name = url.split('?id=')[-1] + 'l'
        #file_name = file_name.split('.')[0] + '.html'
    
        with open(file_name, 'w') as f:
            f.write(resp.text)
