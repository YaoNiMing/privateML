# %%
import numpy as np
import pandas as pd
import os

from sklearn.metrics import accuracy_score
from sklearn.externals import joblib
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix


from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.learning_curve import learning_curve
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingClassifier
# %matplotlib inline

from __future__ import print_function, division
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
# gensim
from gensim import corpora, models, similarities, matutils
# sklearn
from sklearn import datasets
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.cross_validation import train_test_split
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier
import sklearn.metrics.pairwise as smp

from sklearn.decomposition import NMF
# Out:
# /Users/rebeccahyde/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/rebeccahyde/anaconda/lib/python2.7/site-packages/sklearn/learning_curve.py:23: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)
# /Users/rebeccahyde/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /Users/rebeccahyde/anaconda/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")

# %%
result2 = pd.read_pickle('reviews.pkl')

# %%
result2
# Out:
#                                 name  price_level  \
# 0       Stage Door Deli & Restaurant            2
# 1       Stage Door Deli & Restaurant            2
# 2       Stage Door Deli & Restaurant            2
# 3       Stage Door Deli & Restaurant            2
# 4       Stage Door Deli & Restaurant            2
# 5                     Dunkin' Donuts            1
# 6                     Dunkin' Donuts            1
# 7                     Dunkin' Donuts            1
# 8                     Dunkin' Donuts            1
# 9                     Dunkin' Donuts            1
# 10                  NY Pizza Suprema            2
# 11                  NY Pizza Suprema            2
# 12                  NY Pizza Suprema            2
# 13                  NY Pizza Suprema            2
# 14                  NY Pizza Suprema            2
# 15     Pad Thai ( on 8 Ave / 31 St )            2
# 16     Pad Thai ( on 8 Ave / 31 St )            2
# 17     Pad Thai ( on 8 Ave / 31 St )            2
# 18     Pad Thai ( on 8 Ave / 31 St )            2
# 19     Pad Thai ( on 8 Ave / 31 St )            2
# 20                    Dunkin' Donuts            1
# 21               Brother Jimmy's BBQ            2
# 22               Brother Jimmy's BBQ            2
# 23               Brother Jimmy's BBQ            2
# 24               Brother Jimmy's BBQ            2
# 25               Brother Jimmy's BBQ            2
# 26                         Taco Bell            1
# 27                         Taco Bell            1
# 28                         Taco Bell            1
# 29                         Taco Bell            1
# ...                              ...          ...
# 15106          STEM Kitchen & Garden            2
# 15107          STEM Kitchen & Garden            2
# 15108            Mission Rock Resort            2
# 15109            Mission Rock Resort            2
# 15110            Mission Rock Resort            2
# 15111            Mission Rock Resort            2
# 15112            Mission Rock Resort            2
# 15113                         Subway            1
# 15114                         Subway            1
# 15115                         Subway            1
# 15116                       The Ramp            1
# 15117                       The Ramp            1
# 15118                       The Ramp            1
# 15119                       The Ramp            1
# 15120                       The Ramp            1
# 15121         Esposto's Delicatessen            1
# 15122         Esposto's Delicatessen            1
# 15123         Esposto's Delicatessen            1
# 15124         Esposto's Delicatessen            1
# 15125         Esposto's Delicatessen            1
# 15126                    Moshi Moshi            2
# 15127                    Moshi Moshi            2
# 15128                    Moshi Moshi            2
# 15129                    Moshi Moshi            2
# 15130                    Moshi Moshi            2
# 15131                 ATWater Tavern            3
# 15132                 ATWater Tavern            3
# 15133                 ATWater Tavern            3
# 15134                 ATWater Tavern            3
# 15135                 ATWater Tavern            3
#
#                                                     text  rating
# 0      The female who picked up the phone and took my...       1
# 1      We stumbled upon the stage door deli and stage...       5
# 2      Great service, and classic old new york atmosp...       3
# 3      The worst.once it changed owners.the servings ...       1
# 4      Very good place for breakfast with excellent s...       5
# 5      quick service even with long lines.  It's also...       5
# 6      How good can a Dunks be? Well, it's my wife's ...       3
# 7      This is a well staffed Dunkin Donuts which pro...       3
# 8      They always take good care of me here, have us...       3
# 9                               \nIt's a a dunkin baby!        4
# 10     Absolutely the best crust and sauce ever on pi...       5
# 11     This is a pizza place by Penn station. It's pr...       5
# 12     Great variety of pizza. Delicious sauce! Very ...       5
# 13     We were looking for a pizza place to go to and...       5
# 14     Probably the best, fresh pizza i have ever had...       5
# 15     The Pad Thai was the best I've had. Its a smal...       5
# 16     For a dive it was ok on the inside but higher ...       3
# 17     Fan of asian food and posted in Cambodia, I un...       1
# 18     Nice small Thai, Chinese and Japanese restaura...       4
# 19     The food is NOT amazing. In nyc there are much...       2
# 20     Attentive staff, they have gotten my order rig...       5
# 21     Brother Jimmy's is a good spot to go to, but I...       4
# 22     This place is an excellent and affordable stea...       5
# 23     We went8/13 for lunch. It was 95 outside and w...       1
# 24     A decent place for a meal in midtown. Food isn...       3
# 25     My family and I decided to stop by while visit...       1
# 26     Prices are doubled at this location compare to...       1
# 27                               I luv dat baja blast yo       5
# 28     Pretty exp, I know it's NU but so many other d...       3
# 29     Fast and friendly service. Keep away from the ...       5
# ...                                                  ...     ...
# 15106  Incredible food. The cauliflower and quinoa sa...       5
# 15107  I love the view from the restaurant and the op...       4
# 15108  I mostly come here for the view. There is noth...       5
# 15109  Get the fish and chips!!!! And the atmosphere ...       5
# 15110  It's a great place for brunch. Friendly staff....       5
# 15111  This place is well-known for their 99c Oyster ...       5
# 15112  This is a great place.  Great views of the bay...       5
# 15113        i like it quiet and nice to eat your food.        4
# 15114                    Great service, same boring food       4
# 15115  $5 subway. I always hit up this place at least...       5
# 15116  Classic outdoor patio seating in the Dogpatch ...       4
# 15117  great views and great people. live music and g...       5
# 15118  Very fun place on the water, though it didn't ...       4
# 15119  Cool location, kind of rugged but food is good...       5
# 15120  This is the go to place in the Dogpatch area. ...       5
# 15121  Terrible service, false advertising and custom...       1
# 15122  Bought a chicken oriental salad and the noodle...       1
# 15123  As much as I wanted to like this Italian deli,...       2
# 15124  Service=A+ Food=A+ half sandwich with butternu...       5
# 15125  Delicious sandwiches in an unusual spot. Frien...       5
# 15126  My coworkers and I come in here frequently for...       4
# 15127  This is a great place - awesome whiskey select...       5
# 15128  The best bang for your buck is definitely the ...       5
# 15129  Shout out to Jerry who is a wonderful manager,...       5
# 15130  Awesome Japanese food, attentive staff, pricin...       5
# 15131  Have been in here four times now (it's close t...       3
# 15132  I went here for happy hour on a non-game day. ...       5
# 15133  3.5 stars. Nice venue - especially on the pati...       3
# 15134  Delicious food! Portions are more on the small...       5
# 15135  With beautiful bay views, solid cocktails, and...       5
#
# [15136 rows x 4 columns]

# %%
result3=result2
result3['rating'] = result3['rating'].map({1:"negative", 2:'negative', 3:'neutral', 4:'positive', 5:'positive'})

# %%
result3
# Out:
#                                 name  price_level  \
# 0       Stage Door Deli & Restaurant            2
# 1       Stage Door Deli & Restaurant            2
# 2       Stage Door Deli & Restaurant            2
# 3       Stage Door Deli & Restaurant            2
# 4       Stage Door Deli & Restaurant            2
# 5                     Dunkin' Donuts            1
# 6                     Dunkin' Donuts            1
# 7                     Dunkin' Donuts            1
# 8                     Dunkin' Donuts            1
# 9                     Dunkin' Donuts            1
# 10                  NY Pizza Suprema            2
# 11                  NY Pizza Suprema            2
# 12                  NY Pizza Suprema            2
# 13                  NY Pizza Suprema            2
# 14                  NY Pizza Suprema            2
# 15     Pad Thai ( on 8 Ave / 31 St )            2
# 16     Pad Thai ( on 8 Ave / 31 St )            2
# 17     Pad Thai ( on 8 Ave / 31 St )            2
# 18     Pad Thai ( on 8 Ave / 31 St )            2
# 19     Pad Thai ( on 8 Ave / 31 St )            2
# 20                    Dunkin' Donuts            1
# 21               Brother Jimmy's BBQ            2
# 22               Brother Jimmy's BBQ            2
# 23               Brother Jimmy's BBQ            2
# 24               Brother Jimmy's BBQ            2
# 25               Brother Jimmy's BBQ            2
# 26                         Taco Bell            1
# 27                         Taco Bell            1
# 28                         Taco Bell            1
# 29                         Taco Bell            1
# ...                              ...          ...
# 15106          STEM Kitchen & Garden            2
# 15107          STEM Kitchen & Garden            2
# 15108            Mission Rock Resort            2
# 15109            Mission Rock Resort            2
# 15110            Mission Rock Resort            2
# 15111            Mission Rock Resort            2
# 15112            Mission Rock Resort            2
# 15113                         Subway            1
# 15114                         Subway            1
# 15115                         Subway            1
# 15116                       The Ramp            1
# 15117                       The Ramp            1
# 15118                       The Ramp            1
# 15119                       The Ramp            1
# 15120                       The Ramp            1
# 15121         Esposto's Delicatessen            1
# 15122         Esposto's Delicatessen            1
# 15123         Esposto's Delicatessen            1
# 15124         Esposto's Delicatessen            1
# 15125         Esposto's Delicatessen            1
# 15126                    Moshi Moshi            2
# 15127                    Moshi Moshi            2
# 15128                    Moshi Moshi            2
# 15129                    Moshi Moshi            2
# 15130                    Moshi Moshi            2
# 15131                 ATWater Tavern            3
# 15132                 ATWater Tavern            3
# 15133                 ATWater Tavern            3
# 15134                 ATWater Tavern            3
# 15135                 ATWater Tavern            3
#
#                                                     text    rating
# 0      The female who picked up the phone and took my...  negative
# 1      We stumbled upon the stage door deli and stage...  positive
# 2      Great service, and classic old new york atmosp...   neutral
# 3      The worst.once it changed owners.the servings ...  negative
# 4      Very good place for breakfast with excellent s...  positive
# 5      quick service even with long lines.  It's also...  positive
# 6      How good can a Dunks be? Well, it's my wife's ...   neutral
# 7      This is a well staffed Dunkin Donuts which pro...   neutral
# 8      They always take good care of me here, have us...   neutral
# 9                               \nIt's a a dunkin baby!   positive
# 10     Absolutely the best crust and sauce ever on pi...  positive
# 11     This is a pizza place by Penn station. It's pr...  positive
# 12     Great variety of pizza. Delicious sauce! Very ...  positive
# 13     We were looking for a pizza place to go to and...  positive
# 14     Probably the best, fresh pizza i have ever had...  positive
# 15     The Pad Thai was the best I've had. Its a smal...  positive
# 16     For a dive it was ok on the inside but higher ...   neutral
# 17     Fan of asian food and posted in Cambodia, I un...  negative
# 18     Nice small Thai, Chinese and Japanese restaura...  positive
# 19     The food is NOT amazing. In nyc there are much...  negative
# 20     Attentive staff, they have gotten my order rig...  positive
# 21     Brother Jimmy's is a good spot to go to, but I...  positive
# 22     This place is an excellent and affordable stea...  positive
# 23     We went8/13 for lunch. It was 95 outside and w...  negative
# 24     A decent place for a meal in midtown. Food isn...   neutral
# 25     My family and I decided to stop by while visit...  negative
# 26     Prices are doubled at this location compare to...  negative
# 27                               I luv dat baja blast yo  positive
# 28     Pretty exp, I know it's NU but so many other d...   neutral
# 29     Fast and friendly service. Keep away from the ...  positive
# ...                                                  ...       ...
# 15106  Incredible food. The cauliflower and quinoa sa...  positive
# 15107  I love the view from the restaurant and the op...  positive
# 15108  I mostly come here for the view. There is noth...  positive
# 15109  Get the fish and chips!!!! And the atmosphere ...  positive
# 15110  It's a great place for brunch. Friendly staff....  positive
# 15111  This place is well-known for their 99c Oyster ...  positive
# 15112  This is a great place.  Great views of the bay...  positive
# 15113        i like it quiet and nice to eat your food.   positive
# 15114                    Great service, same boring food  positive
# 15115  $5 subway. I always hit up this place at least...  positive
# 15116  Classic outdoor patio seating in the Dogpatch ...  positive
# 15117  great views and great people. live music and g...  positive
# 15118  Very fun place on the water, though it didn't ...  positive
# 15119  Cool location, kind of rugged but food is good...  positive
# 15120  This is the go to place in the Dogpatch area. ...  positive
# 15121  Terrible service, false advertising and custom...  negative
# 15122  Bought a chicken oriental salad and the noodle...  negative
# 15123  As much as I wanted to like this Italian deli,...  negative
# 15124  Service=A+ Food=A+ half sandwich with butternu...  positive
# 15125  Delicious sandwiches in an unusual spot. Frien...  positive
# 15126  My coworkers and I come in here frequently for...  positive
# 15127  This is a great place - awesome whiskey select...  positive
# 15128  The best bang for your buck is definitely the ...  positive
# 15129  Shout out to Jerry who is a wonderful manager,...  positive
# 15130  Awesome Japanese food, attentive staff, pricin...  positive
# 15131  Have been in here four times now (it's close t...   neutral
# 15132  I went here for happy hour on a non-game day. ...  positive
# 15133  3.5 stars. Nice venue - especially on the pati...   neutral
# 15134  Delicious food! Portions are more on the small...  positive
# 15135  With beautiful bay views, solid cocktails, and...  positive
#
# [15136 rows x 4 columns]

# %%
result3["rating"].value_counts()
# Out:
# positive    9591
# negative    4016
# neutral     1529
# Name: rating, dtype: int64

# %%
result3 = result3[result3["price_level"]==1]
result3["rating"].value_counts()
# Out:
# positive    4294
# negative    2599
# neutral      791
# Name: rating, dtype: int64

# %%
count_vectorizer = CountVectorizer(analyzer='word',
                                  ngram_range=(1, 1), stop_words='english', token_pattern="\\b[a-zA-Z][a-zA-Z]+\\b", min_df=2)

# %%
reviews = result3.text
rating = result3.rating
reviews_vecs_cv = count_vectorizer.fit_transform(reviews).transpose()
cv_corpus = matutils.Sparse2Corpus(reviews_vecs_cv)
id2word_cv = dict((v, k) for k, v in count_vectorizer.vocabulary_.iteritems())
# lda_cv = models.LdaModel(corpus_cv, id2word=id2word_cv,  num_topics=3)

# %%
# We need to save a mapping (dict) of row id to word (token) for later use by gensim:
tfidf = TfidfVectorizer(analyzer = "word", ngram_range=(1, 2), stop_words='english', token_pattern="\\b[a-zA-Z][a-zA-Z]+\\b", min_df=10)
# Get the vectors
reviews_vecs_tfidf = tfidf.fit_transform(reviews)
tfidf_corpus = matutils.Sparse2Corpus(reviews_vecs_tfidf.transpose())
id2word = dict((v, k) for k, v in tfidf.vocabulary_.iteritems())

# %%
reviews_vecs_cv.shape
# Out:
# (6127, 7684)

# %%
# Create lda model (equivalent to "fit" in sklearn)
lda= models.LdaModel(cv_corpus, id2word=id2word_cv,  num_topics=50)
lda_corpus=lda[cv_corpus]
reviews_lda = matutils.corpus2dense(lda_corpus, num_terms=50).transpose()
X_train, X_test, y_train, y_test = train_test_split(reviews_lda, rating, 
                                                    test_size=0.33)

# %%
modellist = [KNeighborsClassifier(), LogisticRegression(), MultinomialNB(), DecisionTreeClassifier(), RandomForestClassifier(), SVC(), MLPClassifier(alpha=1), AdaBoostClassifier()]
for model in modellist:
    modelfit = model.fit(X_train, y_train)
    modelypred = modelfit.predict(X_test)
    print (str(model).split("(")[0] + ": " + str(round(accuracy_score(y_test, modelypred),3)))
    print (confusion_matrix(y_test, model.predict(X_test)))
# Out:
# KNeighborsClassifier: 0.663
# [[ 589   39  232]
#  [  79    9  140]
#  [ 276   88 1084]]
# LogisticRegression: 0.744
# [[ 622    0  238]
#  [  67    0  161]
#  [ 183    0 1265]]
# MultinomialNB: 0.731
# [[ 480    0  380]
#  [  34    0  194]
#  [  75    0 1373]]
# DecisionTreeClassifier: 0.63
# [[ 538   88  234]
#  [  73   30  125]
#  [ 267  151 1030]]
# RandomForestClassifier: 0.695
# [[ 599   15  246]
#  [  72   14  142]
#  [ 243   55 1150]]
# SVC: 0.701
# [[ 400    0  460]
#  [  28    0  200]
#  [  69    0 1379]]
# MLPClassifier: 0.744
# [[ 618    0  242]
#  [  67    0  161]
#  [ 179    0 1269]]
# AdaBoostClassifier: 0.733
# [[ 618    2  240]
#  [  59    0  169]
#  [ 203    3 1242]]

# %%
lsi= models.LsiModel(tfidf_corpus, id2word=id2word,  num_topics=500)
lsi_corpus=lsi[tfidf_corpus]
reviews_lsi = matutils.corpus2dense(lsi_corpus, num_terms=500).transpose()
X_train, X_test, y_train, y_test = train_test_split(reviews_lsi+1, rating, 
                                                    test_size=0.33)
modellist = [KNeighborsClassifier(), LogisticRegression(), MultinomialNB(), DecisionTreeClassifier(), RandomForestClassifier(), SVC(), MLPClassifier(alpha=1), AdaBoostClassifier()]
for model in modellist:
    modelfit = model.fit(X_train, y_train)
    modelypred = modelfit.predict(X_test)
    print (str(model).split("(")[0] + ": " + str(round(accuracy_score(y_test, modelypred),3)))
    print (confusion_matrix(y_test, model.predict(X_test)))
# Out:
# KNeighborsClassifier: 0.676
# [[ 362   26  922]
#  [  58   43  386]
#  [ 151   73 2974]]
# LogisticRegression: 0.842
# [[1077   10  223]
#  [ 123   40  324]
#  [  93   14 3091]]
# MultinomialNB: 0.64
# [[   0    0 1310]
#  [   0    0  487]
#  [   0    0 3198]]
# DecisionTreeClassifier: 0.696
# [[ 867  135  308]
#  [ 132   82  273]
#  [ 355  314 2529]]
# RandomForestClassifier: 0.755
# [[ 825   23  462]
#  [ 107   17  363]
#  [ 218   50 2930]]
# SVC: 0.64
# [[   0    0 1310]
#  [   0    0  487]
#  [   0    0 3198]]
# MLPClassifier: 0.79
# [[1203    0  107]
#  [ 224    0  263]
#  [ 455    0 2743]]
# AdaBoostClassifier: 0.807
# [[1034   20  256]
#  [ 134   30  323]
#  [ 208   23 2967]]

# %%
nmf = NMF(n_components=500)
nmf_vecs = nmf.fit_transform(reviews_vecs_tfidf)
X_train, X_test, y_train, y_test = train_test_split(nmf_vecs, rating, 
                                                    test_size=0.33)
modellist = [KNeighborsClassifier(), LogisticRegression(), MultinomialNB(), DecisionTreeClassifier(), RandomForestClassifier(), SVC(), MLPClassifier(alpha=1), AdaBoostClassifier()]
for model in modellist:
    modelfit = model.fit(X_train, y_train)
    modelypred = modelfit.predict(X_test)
    print (str(model).split("(")[0] + ": " + str(round(accuracy_score(y_test, modelypred),3)))
    print (confusion_matrix(y_test, model.predict(X_test)))
# Out:
# KNeighborsClassifier: 0.677
# [[ 822   47  480]
#  [ 149   43  324]
#  [ 523   91 2516]]
# LogisticRegression: 0.668
# [[ 240    0 1109]
#  [  16    0  500]
#  [  35    0 3095]]
# MultinomialNB: 0.628
# [[   8    0 1341]
#  [   0    0  516]
#  [   1    0 3129]]
# DecisionTreeClassifier: 0.717
# [[ 899  153  297]
#  [ 119  111  286]
#  [ 311  248 2571]]
# RandomForestClassifier: 0.787
# [[1019   23  307]
#  [ 127   41  348]
#  [ 221   39 2870]]
# SVC: 0.627
# [[   0    0 1349]
#  [   0    0  516]
#  [   0    0 3130]]
# MLPClassifier: 0.635
# [[  45    0 1304]
#  [   1    0  515]
#  [   4    0 3126]]
# AdaBoostClassifier: 0.8
# [[1039   25  285]
#  [ 122   70  324]
#  [ 195   46 2889]]

# %%
X_train, X_test, y_train, y_test = train_test_split(reviews_vecs_cv, 
                                                    rating, 
                                                    test_size=0.30)
modellist = [KNeighborsClassifier(), LogisticRegression(), MultinomialNB(), DecisionTreeClassifier(), RandomForestClassifier(), SVC(), MLPClassifier(alpha=1), AdaBoostClassifier()]
for model in modellist:
    modelfit = model.fit(X_train, y_train)
    modelypred = modelfit.predict(X_test)
    print (str(model).split("(")[0] + ": " + str(round(accuracy_score(y_test, modelypred),3)))
    print (confusion_matrix(y_test, model.predict(X_test)))
# Out:
# KNeighborsClassifier: 0.715
# [[ 403   31  735]
#  [  35   30  384]
#  [  67   40 2816]]
# LogisticRegression: 0.832
# [[ 937   61  171]
#  [  95   91  263]
#  [  88   83 2752]]
# MultinomialNB: 0.818
# [[ 966   69  134]
#  [ 111   56  282]
#  [ 159   70 2694]]
# DecisionTreeClassifier: 0.754
# [[ 824   86  259]
#  [ 103   95  251]
#  [ 202  214 2507]]
# RandomForestClassifier: 0.806
# [[ 906   19  244]
#  [ 104   38  307]
#  [ 159   46 2718]]
# SVC: 0.66
# [[  78    0 1091]
#  [   1    0  448]
#  [   2    0 2921]]
# MLPClassifier: 0.834
# [[ 925   52  192]
#  [  93   81  275]
#  [  75   65 2783]]
# AdaBoostClassifier: 0.803
# [[ 814   17  338]
#  [  87   43  319]
#  [ 102   32 2789]]

# %%
X_train, X_test, y_train, y_test = train_test_split(reviews_vecs_tfidf, 
                                                    rating, 
                                                    test_size=0.30)

# %%
modellist = [KNeighborsClassifier(), LogisticRegression(), MultinomialNB(), DecisionTreeClassifier(), RandomForestClassifier(), SVC(), MLPClassifier(alpha=1), AdaBoostClassifier()]

# GaussianNB()
# GradientBoostingClassifier()

# %%
for model in modellist:
    modelfit = model.fit(X_train, y_train)
    modelypred = modelfit.predict(X_test)
    print (str(model).split("(")[0] + ": " + str(round(accuracy_score(y_test, modelypred),3)))
    print (confusion_matrix(y_test, model.predict(X_test)))
# Out:
# KNeighborsClassifier: 0.516
# [[192  12 577]
#  [ 57   8 183]
#  [250  36 991]]
# LogisticRegression: 0.825
# [[ 677    3  101]
#  [  61   10  177]
#  [  59    2 1216]]
# MultinomialNB: 0.813
# [[ 671    0  110]
#  [  53    0  195]
#  [  73    0 1204]]
# DecisionTreeClassifier: 0.735
# [[ 584   48  149]
#  [  62   32  154]
#  [ 116   82 1079]]
# RandomForestClassifier: 0.791
# [[ 652    6  123]
#  [  56   15  177]
#  [ 107   13 1157]]
# SVC: 0.554
# [[   0    0  781]
#  [   0    0  248]
#  [   0    0 1277]]
# MLPClassifier: 0.825
# [[ 685    0   96]
#  [  67    1  180]
#  [  60    0 1217]]
# AdaBoostClassifier: 0.761
# [[ 549   15  217]
#  [  51   33  164]
#  [  82   21 1174]]

# %%
tfidf = TfidfVectorizer(analyzer = "word", ngram_range=(1, 2), stop_words='english', token_pattern="\\b[a-zA-Z][a-zA-Z]+\\b", min_df=10)
# Get the vectors
reviews_vecs_tfidf = tfidf.fit_transform(reviews)

# %%
LR = LogisticRegression()
LR.fit(reviews_vecs_tfidf, rating)
X_test=tfidf.transform(["the restaurant was not ok"])
my_prediction = LR.predict(X_test)

# %%
from sklearn.pipeline import Pipeline, FeatureUnion, make_union
model_pipe = Pipeline([
        ("tfidf", tfidf),
        ("model", LogisticRegression())  # Model
        ]).fit(reviews, rating)

# %%
model_pipe.predict(reviews[-5:])
# Out:
# array(['positive', 'positive', 'neutral', 'positive', 'positive'], dtype=object)

# %%
my_prediction
# Out:
# array(['neutral'], dtype=object)

# %%
joblib.dump(model_pipe, 'models/reviewsLR.pkl')
# Out:
# ['models/reviewsLR.pkl']

# %%
estimator = joblib.load('models/reviewsLR.pkl')

# %%
x = estimator.predict(["the restaurant was not ok"])

# %%
x
# Out:
# array(['neutral'], dtype=object)
