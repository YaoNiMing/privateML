# %% [markdown]
# # 6.1

# %%
# 6.1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('/Users/kevin/Downloads/house-votes-84.data', names=['Party']+['X'+str(i) for i in xrange(1,17)])
df.replace('y', 1, inplace=True)
df.replace('n', 0, inplace=True)
df.replace('?', np.nan, inplace=True)
df.fillna(df.mean(),inplace=True)
# Out:
#           Party       X1        X2        X3        X4        X5        X6  \
# 0    republican  0.00000  1.000000  0.000000  1.000000  1.000000  1.000000
# 1    republican  0.00000  1.000000  0.000000  1.000000  1.000000  1.000000
# 2      democrat  0.44208  1.000000  1.000000  0.417453  1.000000  1.000000
# 3      democrat  0.00000  1.000000  1.000000  0.000000  0.504762  1.000000
# 4      democrat  1.00000  1.000000  1.000000  0.000000  1.000000  1.000000
# 5      democrat  0.00000  1.000000  1.000000  0.000000  1.000000  1.000000
# 6      democrat  0.00000  1.000000  0.000000  1.000000  1.000000  1.000000
# 7    republican  0.00000  1.000000  0.000000  1.000000  1.000000  1.000000
# 8    republican  0.00000  1.000000  0.000000  1.000000  1.000000  1.000000
# 9      democrat  1.00000  1.000000  1.000000  0.000000  0.000000  0.000000
# 10   republican  0.00000  1.000000  0.000000  1.000000  1.000000  0.000000
# ...

# %%
from sklearn.cross_validation import train_test_split

X = df.drop(['Party'], axis=1)
y = df.Party
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=4444)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
model_list = [KNeighborsClassifier, LogisticRegression, GaussianNB, SVC, DecisionTreeClassifier, RandomForestClassifier]

for model in model_list:
    y_predict = model().fit(X_train, y_train).predict(X_test)
    print model.__name__, 'Accuracy Score:', accuracy_score(y_test, y_predict)
    print model.__name__, 'Precision Score:', precision_score(y_test, y_predict, pos_label='republican')
    print model.__name__, 'Recall Score:', recall_score(y_test, y_predict, pos_label='republican')
    print model.__name__, 'F1 Score:', f1_score(y_test, y_predict, pos_label='republican')
    print '\n'
# Out:
# KNeighborsClassifier Accuracy Score: 0.916030534351
# KNeighborsClassifier Precision Score: 0.905660377358
# KNeighborsClassifier Recall Score: 0.888888888889
# KNeighborsClassifier F1 Score: 0.897196261682
#
#
# LogisticRegression Accuracy Score: 0.93893129771
# LogisticRegression Precision Score: 0.96
# LogisticRegression Recall Score: 0.888888888889
# LogisticRegression F1 Score: 0.923076923077
#
#
# GaussianNB Accuracy Score: 0.93893129771
# GaussianNB Precision Score: 0.979166666667
# GaussianNB Recall Score: 0.87037037037
# GaussianNB F1 Score: 0.921568627451
#
#
# SVC Accuracy Score: 0.954198473282
# SVC Precision Score: 0.961538461538
# SVC Recall Score: 0.925925925926
# SVC F1 Score: 0.943396226415
#
#
# DecisionTreeClassifier Accuracy Score: 0.946564885496
# DecisionTreeClassifier Precision Score: 0.960784313725
# DecisionTreeClassifier Recall Score: 0.907407407407
# DecisionTreeClassifier F1 Score: 0.933333333333
#
#
# RandomForestClassifier Accuracy Score: 0.946564885496
# ...

# %% [markdown]
# # 6.2

# %%
# 6.2

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %%
model_list = [KNeighborsClassifier(), LogisticRegression(), GaussianNB(), SVC(probability=True), DecisionTreeClassifier(), RandomForestClassifier()]
plt.figure(figsize=(12,5))
for model in model_list:
    prob = model.fit(X_train, y_train).predict_proba(X_test)
    precision, recall, threshold = precision_recall_curve(y_test, prob[:,1], pos_label='republican')
    fpr, tpr, threshold = roc_curve(y_test, prob[:,1], pos_label='republican')
    plt.subplot(1,2,1)
    plt.xlim(0,1)
    plt.ylabel('Recall')
    plt.xlabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.plot(precision, recall, label=model.__str__().split('(')[0])
    plt.legend(loc=0)
    
    plt.subplot(1,2,2)
    plt.plot(fpr, tpr, label=model.__str__().split('(')[0] + ' - AUC: ' + str(auc(fpr, tpr))[:5])
    plt.legend(loc=0)
    plt.ylabel('TPR')
    plt.xlabel('FPR')
    plt.title('ROC Curve')

# %% [markdown]
# # 6.3

# %%
# 6.3

df = pd.read_csv('/Users/kevin/Downloads/haberman.data', names=['Age','Year','Nodes','Survived'])
df
# Out:
#      Age  Year  Nodes  Survived
# 0     30    64      1         1
# 1     30    62      3         1
# 2     30    65      0         1
# 3     31    59      2         1
# 4     31    65      4         1
# 5     33    58     10         1
# 6     33    60      0         1
# 7     34    59      0         2
# 8     34    66      9         2
# 9     34    58     30         1
# 10    34    60      1         1
# 11    34    61     10         1
# 12    34    67      7         1
# 13    34    60      0         1
# 14    35    64     13         1
# 15    35    63      0         1
# 16    36    60      1         1
# 17    36    69      0         1
# 18    37    60      0         1
# 19    37    63      0         1
# 20    37    58      0         1
# 21    37    59      6         1
# 22    37    60     15         1
# 23    37    63      0         1
# 24    38    69     21         2
# 25    38    59      2         1
# 26    38    60      0         1
# 27    38    60      0         1
# ...

# %%
X = df.drop('Survived', axis = 1)
y = df.Survived
y[y==2] = 0
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 4444)

# %%
prob = LogisticRegression().fit(X_train, y_train).predict_proba(X_test)
precision, recall, threshold = precision_recall_curve(y_test, prob[:,1])
fpr, tpr, threshold = roc_curve(y_test, prob[:,1])

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.xlim(0,1)
plt.ylim(0,1)
plt.ylabel('Recall')
plt.xlabel('Precision')
plt.title('Precision-Recall Curve')
plt.plot(precision, recall, label='Logistic Regression')
plt.legend(loc=0)

plt.subplot(1,2,2)
plt.plot(fpr, tpr, 'g', label='Logistic Regression - AUC: ' + str(auc(fpr, tpr))[:5])
plt.legend(loc=0)
plt.xlim(0,1)
plt.ylim(0,1)
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.title('ROC Curve');
